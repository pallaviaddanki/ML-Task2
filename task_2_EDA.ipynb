# %% [markdown]
# # Step 1: Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew

# %% [markdown]
# # Step 2: Load data

# %%
df = pd.read_csv("/content/carona.csv")
df.head()
# Out:
# <ipython-input-5-100f0ee15212>:1: DtypeWarning: Columns (2,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/carona.csv")
#    Ind_ID   Test_date Cough_symptoms  Fever Sore_throat Shortness_of_breath  \
# 0       1  11-03-2020           True  False        True               False
# 1       2  11-03-2020          False   True       False               False
# 2       3  11-03-2020          False   True       False               False
# 3       4  11-03-2020           True  False       False               False
# 4       5  11-03-2020           True  False       False               False
#
#   Headache    Corona Age_60_above  Sex           Known_contact
# 0    False  negative          NaN  NaN                  Abroad
# 1    False  positive          NaN  NaN                  Abroad
# 2    False  positive          NaN  NaN                  Abroad
# 3    False  negative          NaN  NaN                  Abroad
# ...

# %% [markdown]
# # Step 3: Basic info and summary

# %%
print("Dataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157843 entries, 0 to 157842
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Ind_ID               157843 non-null  int64
#  1   Test_date            157843 non-null  object
#  2   Cough_symptoms       157591 non-null  object
#  3   Fever                157591 non-null  object
#  4   Sore_throat          157842 non-null  object
#  5   Shortness_of_breath  157842 non-null  object
#  6   Headache             157842 non-null  object
#  7   Corona               157842 non-null  object
#  8   Age_60_above         151528 non-null  object
#  9   Sex                  140210 non-null  object
#  10  Known_contact        157842 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 13.2+ MB

# %%
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#               Ind_ID
# count  157843.000000
# mean    78922.000000
# std     45565.493607
# min         1.000000
# 25%     39461.500000
# 50%     78922.000000
# 75%    118382.500000
# max    157843.000000

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Ind_ID                     0
# Test_date                  0
# Cough_symptoms           252
# Fever                    252
# Sore_throat                1
# Shortness_of_breath        1
# Headache                   1
# Corona                     1
# Age_60_above            6315
# Sex                    17633
# Known_contact              1
# dtype: int64

# %% [markdown]
# # Step 4: Histograms and Boxplots

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns

# %%
for col in numeric_cols:
    plt.figure(figsize=(12, 5))

# %% [markdown]
#    # Histogram

# %%
# Step 4: Histograms and Boxplots
numeric_cols = df.select_dtypes(include=[np.number]).columns

for col in numeric_cols:
    plt.figure(figsize=(12, 5))

    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(df[col].dropna(), kde=True)
    plt.title(f'Histogram of {col}')

    # Boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')

    plt.tight_layout()
    plt.show()

# %% [markdown]
#   # Boxplot

# %%
for col in numeric_cols:
    plt.figure(figsize=(12, 5))

    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(df[col].dropna(), kde=True)
    plt.title(f'Histogram of {col}')

    # Boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col].dropna())
    plt.title(f'Boxplot of {col}')

    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

# Select categorical columns (excluding IDs and dates)
categorical_cols = ['Cough_symptoms', 'Fever', 'Sore_throat',
                    'Shortness_of_breath', 'Headache', 'Corona',
                    'Age_60_above', 'Sex', 'Known_contact']

for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col, order=df[col].value_counts().index)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
